# %% [markdown]
# # Práctica 1.1 — Probabilidad y Estadística
# ## Análisis de la evolución poblacional mundial
# ### Deborah Villicaña Prieto
#
# Objetivo: Reconocer la procedencia del conjunto de datos antes de utilizarlo y documentar correctamente su fuente.
#
# Los datos utilizados en esta práctica provienen de **Our World in Data (OWID)**.
#
# La fuente original es **United Nations, World Population Prospects (2024)**.
# **Cita:**
# > UN, World Population Prospects (2024) – processed by Our World in Data. “Annual change in population – UN WPP” [dataset]. United Nations, “World Population Prospects”; United Nations, “World Population Prospects - Interim Update” [original data].
#
# Preguntas:
# 1.	¿Quién produjo originalmente los datos? La ONU.
# 2.	¿Qué organización los procesa para su utilización en Our World in Data? Global Change Data Lab
# 3.	¿Qué representa la variable que analizarás? La variable "Annual Change in Population" representa el cambio anual de la población de cada país. Con esto se puede sabaer si está incrementando o disminuyendo.

# %% [markdown]
# # Actividad 2 - Carga y exploración de datos
# ## Objetivo: Comprobar que el entorno de Python, Pandas y Jupyter funciona correctamente y realizar una primera exploración del dataset.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\\Users\\debor\\Documents\\Deborah\\ISSC\\5to\\Big Data\\U1_1_probabilidad_estadistica\\data\\raw\\annual-population-growth\\annual-population-growth.csv")

# %%
df.head(3)
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN

# %%
#Extracción de datos.
df["Entity"]
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 38395       Zimbabwe
# 38396       Zimbabwe
# 38397       Zimbabwe
# 38398       Zimbabwe
# 38399       Zimbabwe
# Name: Entity, Length: 38400, dtype: str

# %%
df.shape
# Out:
# (38400, 5)

# %%
df.dtypes
# Out:
# Entity                                      str
# Code                                        str
# Year                                      int64
# Annual change in population             float64
# Annual population change (Projected)    float64
# dtype: object

# %%
df.columns.tolist()
# Out:
# ['Entity',
#  'Code',
#  'Year',
#  'Annual change in population',
#  'Annual population change (Projected)']

# %%
df.describe()
# Out:
#                Year  Annual change in population  \
# count  38400.000000                 1.868800e+04
# mean    2025.500000                 2.063019e+06
# std       43.300872                 9.440859e+06
# min     1951.000000                -3.315935e+06
# 25%     1988.000000                 1.781000e+03
# 50%     2025.500000                 4.689800e+04
# 75%     2063.000000                 3.021128e+05
# max     2100.000000                 9.337137e+07
#
#        Annual population change (Projected)
# count                          1.971200e+04
# mean                           8.375481e+05
# std                            5.816745e+06
# min                           -2.291035e+07
# 25%                           -9.742750e+03
# 50%                            9.350000e+01
# 75%                            1.411160e+05
# max                            7.206736e+07

# %%
df.isnull().sum()
# Out:
# Entity                                      0
# Code                                     1200
# Year                                        0
# Annual change in population             19712
# Annual population change (Projected)    18688
# dtype: int64

# %%
df["Entity"].unique() #Muestra todos los datos únicos
# Out:
# <StringArray>
# [        'Afghanistan',         'Africa (UN)',             'Albania',
#              'Algeria',      'American Samoa',       'Americas (UN)',
#              'Andorra',              'Angola',            'Anguilla',
#  'Antigua and Barbuda',
#  ...
#              'Vanuatu',             'Vatican',           'Venezuela',
#              'Vietnam',   'Wallis and Futuna',      'Western Sahara',
#                'World',               'Yemen',              'Zambia',
#             'Zimbabwe']
# Length: 256, dtype: str

# %%
df["Entity"].nunique() #CUENTA los datos únicos
# Out:
# 256

# %%
#Filtrar año 2020 y se asigna a un nuevo DataFrame
df_2020 = df[df["Year"]==2020]
df_2020.head(3)

#Los índices corresponden al df original
# Out:
#           Entity    Code  Year  Annual change in population  \
# 69   Afghanistan     AFG  2020                    1212852.0
# 219  Africa (UN)  UN_AFR  2020                   32815675.0
# 369      Albania     ALB  2020                     -13061.0
#
#      Annual population change (Projected)
# 69                                    NaN
# 219                                   NaN
# 369                                   NaN

# %%
df_2020_ext_col1 = df_2020[["Entity", "Year"]]
df_2020_ext_col1.head(3)

#de manera simplificada en una sola línea
df_2020_ext_col2 = df[df["Year"]==2020][["Entity", "Year"]]
df_2020_ext_col2.head(3)
# Out:
#           Entity  Year
# 69   Afghanistan  2020
# 219  Africa (UN)  2020
# 369      Albania  2020

# %%
#Rango de fechas
df_2005_2020 = df[(df["Year"]>= 2005)&(df["Year"] <=2020)]
df_2005_2020.head(3)
#df_2005_2020.shape
# Out:
#          Entity Code  Year  Annual change in population  \
# 54  Afghanistan  AFG  2005                     843919.0
# 55  Afghanistan  AFG  2006                    1019525.0
# 56  Afghanistan  AFG  2007                     485752.0
#
#     Annual population change (Projected)
# 54                                   NaN
# 55                                   NaN
# 56                                   NaN

# %%
df_2005_2020_mx = df[(df["Year"]>= 2005) & (df["Year"] <=2020) & (df["Entity"]=="Mexico")]
df_2005_2020_mx.shape
# Out:
# (16, 5)

# %%
df_ext_EA = df_2005_2020_mx[["Entity", "Annual change in population"]]
df_ext_EA.head(3)
# Out:
#        Entity  Annual change in population
# 22254  Mexico                    1417373.0
# 22255  Mexico                    1442162.0
# 22256  Mexico                    1520690.0

# %%
df_ext_EA.mean(numeric_only=True)
# Out:
# Annual change in population    1400307.625
# dtype: float64

# %% [markdown]
# 1.	¿Cuántas filas y columnas tiene el dataset? 38400 filas, 5 columnas
# 2.	¿Qué tipo de datos contiene la variable Year? int64
# 3.	¿Existen valores faltantes? Sí, en Code, Annual change in population y Annual population change (Projected)
# 4.	¿Cuántas entidades diferentes contiene el dataset? 256

# %% [markdown]
# # Actividad 3 - Estadística Descriptiva

# %%
#país primer apellido: Vietnam
df_vietnam = df[(df["Entity"] =="Vietnam") & (df["Year"] >= 1983) & (df["Year"] <= 2021)]
df_vietnam.describe()
# Out:
#               Year  Annual change in population  \
# count    39.000000                 3.900000e+01
# mean   2002.000000                 1.126252e+06
# std      11.401754                 2.102038e+05
# min    1983.000000                 7.493320e+05
# 25%    1992.500000                 9.914570e+05
# 50%    2002.000000                 1.106511e+06
# 75%    2011.500000                 1.295271e+06
# max    2021.000000                 1.542415e+06
#
#        Annual population change (Projected)
# count                                   0.0
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN

# %%
#Variable: "Annual change in population" cual pais tiene el min y max de cambio en poblacion anual
df_acp = df[["Entity", "Annual change in population"]]
df_acp.min(numeric_only=True)
# Out:
# Annual change in population   -3315935.0
# dtype: float64

# %%
df_acp.max()
# Out:
# Entity                           Zimbabwe
# Annual change in population    93371370.0
# dtype: object

# %%
df_acp.median(numeric_only=True)
# Out:
# Annual change in population    46898.0
# dtype: float64

# %%
df_acp = df[df["Entity"] == "Ukraine"]
df_acp.min()
# Out:
# Entity                                    Ukraine
# Code                                          UKR
# Year                                         1951
# Annual change in population            -3315935.0
# Annual population change (Projected)    -376640.0
# dtype: object

# %%
df_acp_min = df_acp[df_acp["Annual change in population"] == -3315935.0]
df_acp_min
# Out:
#         Entity Code  Year  Annual change in population  \
# 35772  Ukraine  UKR  2023                   -3315935.0
#
#        Annual population change (Projected)
# 35772                                   NaN

# %% [markdown]
# Preguntas
# Responde brevemente:
# 1.	¿Cuál es el valor de la media? 1.126252e
# 2.	¿Cuál es el valor de la mediana? 46898.0
# 3.	¿Cuál es el valor de la desviación estándar? 2.102038e
# 4.	¿Qué entidad presenta el valor mínimo y cuál el máximo? Ukraine el mínimo y Zimbabwe el máximo

# %% [markdown]
# # Actividad 4
# Propósito:
# Comprobar que el notebook está utilizando correctamente las herramientas configuradas para la práctica.

# %%
import sys

print("Python:", sys.version)
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Python: 3.14.2 (tags/v3.14.2:df79316, Dec  5 2025, 17:18:21) [MSC v.1944 64 bit (AMD64)]
# Pandas: 3.0.5
# NumPy: 2.5.2

# %% [markdown]
# # Ejercicios loc iloc

# %%
df.iloc[:,0:2]
# Out:
#             Entity Code
# 0      Afghanistan  AFG
# 1      Afghanistan  AFG
# 2      Afghanistan  AFG
# 3      Afghanistan  AFG
# 4      Afghanistan  AFG
# ...            ...  ...
# 38395     Zimbabwe  ZWE
# 38396     Zimbabwe  ZWE
# 38397     Zimbabwe  ZWE
# 38398     Zimbabwe  ZWE
# 38399     Zimbabwe  ZWE
#
# [38400 rows x 2 columns]

# %%
df.loc[10000]
# Out:
# Entity                                  Equatorial Guinea
# Code                                                  GNQ
# Year                                                 2051
# Annual change in population                           NaN
# Annual population change (Projected)              46407.0
# Name: 10000, dtype: object

# %%
df.loc[:, ["Entity", "Year", "Annual change in population"]] #: porque quiero que muestre todas las filas
# Out:
#             Entity  Year  Annual change in population
# 0      Afghanistan  1951                     103163.0
# 1      Afghanistan  1952                     108441.0
# 2      Afghanistan  1953                     108919.0
# 3      Afghanistan  1954                     111251.0
# 4      Afghanistan  1955                     119027.0
# ...            ...   ...                          ...
# 38395     Zimbabwe  2096                          NaN
# 38396     Zimbabwe  2097                          NaN
# 38397     Zimbabwe  2098                          NaN
# 38398     Zimbabwe  2099                          NaN
# 38399     Zimbabwe  2100                          NaN
#
# [38400 rows x 3 columns]

# %%
df.iloc[:, [0,2,3]] #orden entre corchetes: filas, columnas
# Out:
#             Entity  Year  Annual change in population
# 0      Afghanistan  1951                     103163.0
# 1      Afghanistan  1952                     108441.0
# 2      Afghanistan  1953                     108919.0
# 3      Afghanistan  1954                     111251.0
# 4      Afghanistan  1955                     119027.0
# ...            ...   ...                          ...
# 38395     Zimbabwe  2096                          NaN
# 38396     Zimbabwe  2097                          NaN
# 38397     Zimbabwe  2098                          NaN
# 38398     Zimbabwe  2099                          NaN
# 38399     Zimbabwe  2100                          NaN
#
# [38400 rows x 3 columns]

# %%
df.loc[10000, ["Entity", "Year", "Annual change in population"]]
# Out:
# Entity                         Equatorial Guinea
# Year                                        2051
# Annual change in population                  NaN
# Name: 10000, dtype: object

# %%
df.iloc[10000, [0,2,3]]
# Out:
# Entity                         Equatorial Guinea
# Year                                        2051
# Annual change in population                  NaN
# Name: 10000, dtype: object

# %%
df.loc[(df["Entity"] == "Mexico") & (df["Year"] == 2020)]
# Out:
#        Entity Code  Year  Annual change in population  \
# 22269  Mexico  MEX  2020                    1036075.0
#
#        Annual population change (Projected)
# 22269                                   NaN

# %%
df.set_index("Entity")
df.head
# Out:
# <bound method NDFrame.head of             Entity Code  Year  Annual change in population  \
# 0      Afghanistan  AFG  1951                     103163.0
# 1      Afghanistan  AFG  1952                     108441.0
# 2      Afghanistan  AFG  1953                     108919.0
# 3      Afghanistan  AFG  1954                     111251.0
# 4      Afghanistan  AFG  1955                     119027.0
# ...            ...  ...   ...                          ...
# 38395     Zimbabwe  ZWE  2096                          NaN
# 38396     Zimbabwe  ZWE  2097                          NaN
# 38397     Zimbabwe  ZWE  2098                          NaN
# 38398     Zimbabwe  ZWE  2099                          NaN
# 38399     Zimbabwe  ZWE  2100                          NaN
#
#        Annual population change (Projected)
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# ...
